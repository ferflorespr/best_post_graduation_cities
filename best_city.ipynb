# %% [markdown]
# <a href="https://colab.research.google.com/github/ferflorespr/best_post_graduation_cities/blob/main/best_city.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# File: visualization_api.ipynb

# Core Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Optional: Interactive Visuals
import plotly.express as px

# Suppress Warnings (optional)
import warnings
warnings.filterwarnings('ignore')

print("Visualization API Notebook Initialized")
# Out:
# Visualization API Notebook Initialized

# %%
# Function to load data (supports CSV for now)
def load_data(filepath):
    """
    Load data from CSV file.
    """
    try:
        data = pd.read_csv('SofwareDeveloperIncomeExpensesperUSACity.csv')
        print(f"Loaded dataset with shape {data.shape}")
        return data
    except Exception as e:
        print(f"Error loading data: {e}")

# %%
# Function for Quick Summary
def summarize_data(df):
    """
    Display basic summary of the dataset.
    """
    display(df.head())
    print("\nData Summary:")
    print(df.describe())
    print("\nMissing Values:")
    print(df.isnull().sum())

# %%
# Scatter Plot with Plotly
def scatter_plot(df, x_col, y_col, color_col=None, title="Scatter Plot"):
    """
    Generate an interactive scatter plot.
    """
    fig = px.scatter(df, x=x_col, y=y_col, color=color_col, title=title)
    fig.show()

# %%
# Example
data = load_data('SofwareDeveloperIncomeExpensesperUSACity.csv')
summarize_data(data)

scatter_plot(data,
             x_col='Cost of Living avg',
             y_col='Mean Software Developer Salary (adjusted)',
             color_col='City',
             title='Adjusted Salary vs Cost of Living (by City)')



# Compute Salary-to-Cost-of-Living Ratio


data['Salary_to_COL'] = data['Mean Software Developer Salary (adjusted)'] / data['Cost of Living avg']

# Sort and display top 10 cities with the best ratio
top_cities = data.sort_values('Salary_to_COL', ascending=False)[['City', 'Salary_to_COL', 'Mean Software Developer Salary (adjusted)', 'Cost of Living avg']]

top_cities.head(10)
# Out:
# Loaded dataset with shape (77, 12)
#    Unnamed: 0                              Metro  \
# 0           0                       Columbus, OH
# 1           1        Seattle-Tacoma-Bellevue, WA
# 2           2  Charlotte-Concord-Gastonia, NC-SC
# 3           3               Colorado Springs, CO
# 4           4                         Dayton, OH
#
#    Mean Software Developer Salary (adjusted)  \
# 0                                   117552.0
# 1                                   117323.0
# 2                                   114122.0
# 3                                   112118.0
# 4                                   111616.0
#
#    Mean Software Developer Salary (unadjusted)  \
# 0                                     108500.0
# 1                                     131167.0
# 2                                     107046.0
# 3                                     111670.0
# 4                                      99338.0
#
#    Mean Unadjusted Salary (all occupations)  \
# 0                                   51260.0
# 1                                   65400.0
# 2                                   51000.0
# 3                                   51430.0
# 4                                   50100.0
#
#    Number of Software Developer Jobs  Median Home Price                  City  \
# 0                            13430.0           192000.0          Columbus, OH
# 1                            65760.0           491600.0           Seattle, WA
# 2                            12800.0           208500.0         Charlotte, NC
# 3                             5780.0           296500.0  Colorado Springs, CO
# 4                             4240.0           124100.0            Dayton, OH
#
#    Cost of Living avg  Rent avg  Cost of Living Plus Rent avg  \
# 0               984.8    1421.5                        2856.5
# 1              1250.7    2528.2                        4091.5
# 2               989.9    1974.5                        3221.1
# 3              1049.2    1594.0                        3094.5
# 4               961.2    1072.1                        2586.0
#
#    Local Purchasing Power avg
# 0                      9335.4
# 1                      8971.3
# 2                      8939.8
# 3                      8493.1
# 4                      4887.7
# Data Summary:
#        Unnamed: 0  Mean Software Developer Salary (adjusted)  \
# count   77.000000                                  77.000000
# mean    38.000000                              100832.974026
# std     22.371857                                8064.298677
# min      0.000000                               72811.000000
# 25%     19.000000                               95308.000000
# 50%     38.000000                              101256.000000
# 75%     57.000000                              107170.000000
# max     76.000000                              117552.000000
#
#        Mean Software Developer Salary (unadjusted)  \
# count                                    77.000000
# mean                                 101866.207792
# std                                   13926.636588
# min                                   80314.000000
# 25%                                   91976.000000
# 50%                                  100614.000000
# 75%                                  109503.000000
# max                                  142101.000000
#
#        Mean Unadjusted Salary (all occupations)  \
# count                                 77.000000
# mean                               53277.272727
# std                                 7813.343788
# min                                44500.000000
# 25%                                48240.000000
# 50%                                51050.000000
# 75%                                56160.000000
# max                                80480.000000
#
#        Number of Software Developer Jobs  Median Home Price  \
# count                          77.000000       7.700000e+01
# mean                        19098.571429       3.127013e+05
# std                         23858.147274       2.227433e+05
# min                          1120.000000       1.241000e+05
# 25%                          3170.000000       1.784000e+05
# 50%                          8770.000000       2.437000e+05
# 75%                         21160.000000       3.660000e+05
# max                         98650.000000       1.193600e+06
#
#        Cost of Living avg      Rent avg  Cost of Living Plus Rent avg  \
# count           77.000000     77.000000                     77.000000
# mean          1414.057143   3280.429870                   6506.988312
# std           2369.540953   9118.805313                  20325.065018
# min            832.500000    879.300000                   2241.400000
# 25%            957.300000   1340.500000                   2810.800000
# 50%            995.000000   1625.800000                   2999.900000
# 75%           1086.000000   2171.900000                   3446.900000
# max          15809.200000  58597.600000                 130097.800000
#
#        Local Purchasing Power avg
# count                   77.000000
# mean                  7421.228571
# std                   1327.443694
# min                   4840.100000
# 25%                   6464.200000
# 50%                   7499.000000
# 75%                   8153.100000
# max                  10673.700000
#
# Missing Values:
# Unnamed: 0                                     0
# Metro                                          0
# Mean Software Developer Salary (adjusted)      0
# Mean Software Developer Salary (unadjusted)    0
# Mean Unadjusted Salary (all occupations)       0
# Number of Software Developer Jobs              0
# Median Home Price                              0
# City                                           0
# Cost of Living avg                             0
# Rent avg                                       0
# Cost of Living Plus Rent avg                   0
# Local Purchasing Power avg                     0
# dtype: int64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f75bf28a-527a-464e-b6bb-5efc4c23fe49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f75bf28a-527a-464e-b6bb-5efc4c23fe49")) {                    Plotly.newPlot(                        "f75bf28a-527a-464e-b6bb-5efc4c23fe49",                        [{"hovertemplate":"City=Columbus, OH\u003cbr\u003eCost of Living avg=%{x}\u003cbr\u003eMean Software Developer Salary (adjusted)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Columbus, OH","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Columbus, OH","orientation":"v","showlegend":true,"x":[984.8],"xaxis":"x","y":[117552.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"City=Seattle, WA\u003cbr\u003eCost of Living avg=%{x}\u003cbr\u003eMean Software Developer Salary (adjusted)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Seattle, WA","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Seattle, WA","orientation":"v","showlegend":true,"x":[1250.7],"xaxis":"x","y":[117323.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"City=Charlotte, NC\u003cbr\u003eCost of Living avg=%{x}\u003cbr\u003eMean Software Developer Salary (adjusted)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Charlotte, NC","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Charlotte, NC","orientation":"v","showlegend":true,"x":[989.9],"xaxis":"x","y":[114122.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"City=Colorado Springs, CO\u003cbr\u003eCost of Living avg=%{x}\u003cbr\u003eMean Software Developer Salary (adjusted)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colorado Springs, CO","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Colorado Springs, CO","orientation":"v","showlegend":true,"x":[1049.2],"xaxis":"x","y":[112118.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"City=Dayton, OH\u003cbr\u003eCost of Living avg=%{x}\u003cbr\u003eMean Software Developer Salary (adjusted)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Dayton, OH","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Dayton, OH","orientation":"v","showlegend":true,"x":[961.2],"xaxis":"x","y":[111616.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"City=Greensboro, NC\u003cbr\u003eCost of Living avg=%{x}\u003cbr\u003eMean Software Developer Salary (adjusted)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Greensboro, NC","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Greensboro, NC","orientation":"v","showlegend":true,"x":[992.9],"xaxis":"x","y":[111050.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"City=San Francisco, CA\u003cbr\u003eCost of Living avg=%{x}\u003cbr\u003eMean Software Developer Salary (adjusted)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"San Francisco, CA","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"San Francisco, CA","orientation":"v","showlegend":true,"x":[1326.9],"xaxis":"x","y":[111017.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"City=Oakland, CA\u003cbr\u003eCost of Living avg=%{x}\u003cbr\u003eMean Software Developer Salary (adjusted)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oakland, CA","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Oakland, CA","orientation":"v","showlegend":true,"x":[1313.0],"xaxis":"x","y":[111017.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"City=San Antonio, TX\u003cbr\u003eCost of Living avg=%{x}\u003cbr\u003eMean Software Developer Salary (adjusted)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"San Antonio, TX","marker":{"color":"#FF97FF","symbol ...
#                   City  Salary_to_COL  \
# 8      San Antonio, TX     125.407667
# 28         Wichita, KS     124.552553
# 13      Cincinnati, OH     119.820840
# 0         Columbus, OH     119.366369
# 16         Houston, TX     119.185300
# 22       Lexington, KY     118.389201
# 19          Tucson, AZ     117.885821
# 4           Dayton, OH     116.121515
# 14          Austin, TX     115.996169
# 20  Salt Lake City, UT     115.823254
#
#     Mean Software Developer Salary (adjusted)  Cost of Living avg
# 8                                    110898.0               884.3
# 28                                   103690.0               832.5
# 13                                   109013.0               909.8
# 0                                    117552.0               984.8
# 16                                   107672.0               903.4
# 22                                   105248.0               889.0
# 19                                   107170.0               909.1
# 4                                    111616.0               961.2
# 14                                   108990.0               939.6
# 20                                   106291.0               917.7
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
# prompt: using original csv file, lets generate a ranking of the Number of Software Developer Jobs in each city, showing in the right column Number of Software Developer Jobs in each city

# Generate a ranking of the Number of Software Developer Jobs in each city
job_ranking = data.groupby('City')['Number of Software Developer Jobs'].sum().sort_values(ascending=False).reset_index()
job_ranking.rename(columns={'Number of Software Developer Jobs': 'Number of Software Developer Jobs in each city'}, inplace=True)

print("\nRanking of Cities by Number of Software Developer Jobs:")
job_ranking
# Out:
# Ranking of Cities by Number of Software Developer Jobs:
#                 City  Number of Software Developer Jobs in each city
# 0    Jersey City, NJ                                         98650.0
# 1       New York, NY                                         98650.0
# 2    Santa Clara, CA                                         78730.0
# 3       San Jose, CA                                         78730.0
# 4        Seattle, WA                                         65760.0
# ..               ...                                             ...
# 72        Eugene, OR                                          1220.0
# 73       Wichita, KS                                          1220.0
# 74  Fort Collins, CO                                          1190.0
# 75     Lexington, KY                                          1140.0
# 76       Spokane, WA                                          1120.0
#
# [77 rows x 2 columns]

# %%
# prompt: Using dataframe job_ranking: now lets take tgose top 15 and put them on a map, try different library

import plotly.express as px

# Sort the dataframe by the number of jobs and select the top 15 cities
top_cities = job_ranking.nlargest(15, 'Number of Software Developer Jobs in each city')

# Split the 'City' column into 'City' and 'State'
top_cities[['City_Name', 'State']] = top_cities['City'].str.split(', ', expand=True)

# Create a scatter map using Plotly Express
fig = px.scatter_geo(top_cities,
                     locations="State",
                     locationmode="USA-states",
                     size="Number of Software Developer Jobs in each city",
                     hover_name="City",
                     scope="usa",
                     title="Top 15 Cities by Number of Software Developer Jobs")

# Show the map
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fdaf3f22-03db-48d7-8fbe-95ab2ee094fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fdaf3f22-03db-48d7-8fbe-95ab2ee094fb")) {                    Plotly.newPlot(                        "fdaf3f22-03db-48d7-8fbe-95ab2ee094fb",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eNumber of Software Developer Jobs in each city=%{marker.size}\u003cbr\u003eState=%{location}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Jersey City, NJ","New York, NY","Santa Clara, CA","San Jose, CA","Seattle, WA","Washington, DC","Oakland, CA","San Francisco, CA","Boston, MA","Long Beach, CA","Los Angeles, CA","Dallas, TX","Fort Worth, TX","Chicago, IL","Atlanta, GA"],"legendgroup":"","locationmode":"USA-states","locations":["NJ","NY","CA","CA","WA","DC","CA","CA","MA","CA","CA","TX","TX","IL","GA"],"marker":{"color":"#636efa","size":[98650.0,98650.0,78730.0,78730.0,65760.0,63760.0,59550.0,59550.0,54140.0,53190.0,53190.0,46130.0,46130.0,42090.0,38110.0],"sizemode":"area","sizeref":246.625,"symbol":"circle"},"mode":"markers","name":"","showlegend":false,"type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpatte ...

# %%
import plotly.express as px
import pandas as pd

# Assuming your `top_cities` DataFrame is ready from previous code
# And `rent_df` has been loaded with state rent info

# --- 1. Merge Rent Data with top_cities ---
top_cities[['City_Name', 'State']] = top_cities['City'].str.split(', ', expand=True)
merged_df = pd.merge(top_cities, rent_df, on='State', how='left')

# --- 2. Base Map with Rent as Heatmap Coloring ---
fig = px.choropleth(locations=rent_df['State'],
                    locationmode="USA-states",
                    color=rent_df['Avg Rent ($)'],
                    scope="usa",
                    color_continuous_scale="Reds",
                    labels={'color':'Avg Rent ($)'},
                    title="Top 15 Cities by Dev Jobs + Rent Heatmap")

# --- 3. Overlay City Scatter on Top ---
fig.add_scattergeo(locations=merged_df['State'],
                   locationmode="USA-states",
                   text=merged_df['City'],
                   hovertext=merged_df['City'],
                   marker=dict(size=merged_df['Number of Software Developer Jobs in each city'] / 2000,
                               color='blue',
                               line_width=0.5),
                   name="Cities")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="36398613-e074-44e1-9d7f-9041cc840323" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36398613-e074-44e1-9d7f-9041cc840323")) {                    Plotly.newPlot(                        "36398613-e074-44e1-9d7f-9041cc840323",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"locations=%{location}\u003cbr\u003eAvg Rent ($)=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"USA-states","locations":["AL","AK","AZ","AR","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"],"name":"","z":[1122,1271,1641,926,2101,1682,1464,1713,1752,1339,2132,1483,1221,1066,1136,1159,945,825,1565,1669,1703,995,840,1127,910,1323,850,1452,1442,1758,1295,1394,1348,905,982,1129,1241,1012,1338,1301,901,1326,1347,1584,1222,1507,1785,693,1088,1102],"type":"choropleth"},{"hovertext":["Jersey City, NJ","New York, NY","Santa Clara, CA","San Jose, CA","Seattle, WA","Washington, DC","Oakland, CA","San Francisco, CA","Boston, MA","Long Beach, CA","Los Angeles, CA","Dallas, TX","Fort Worth, TX","Chicago, IL","Atlanta, GA"],"locationmode":"USA-states","locations":["NJ","NY","CA","CA","WA","DC","CA","CA","MA","CA","CA","TX","TX","IL","GA"],"marker":{"color":"blue","line":{"width":0.5},"size":[49.325,49.325,39.365,39.365,32.88,31.88,29.775,29.775,27.07,26.595,26.595,23.065,23.065,21.045,19.055]},"name":"Cities","text":["Jersey City, NJ","New York, NY","Santa Clara, CA","San Jose, CA","Seattle, WA","Washington, DC","Oakland, CA","San Francisco, CA","Boston, MA","Long Beach, CA","Los Angeles, CA","Dallas, TX","Fort Worth, TX","Chicago, IL","Atlanta, GA"],"type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444 ...
